# %%
df = spark.read.option("multiline", "true").json("Files/bing-latest-news.json")
# df now is a Spark DataFrame containing JSON data from "Files/bing-latest-news.json".
display(df)
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e3bb35b4-179c-4184-b959-d7cadb152998)

# %%
df = df.select("value")
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 4, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ac707de8-5553-4146-8eb0-df16edd15a78)

# %%
from pyspark.sql.functions import explode

df_explode = df.select(explode(df["value"]).alias("json_object"))
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 6, Finished, Available, Finished)

# %%
display(df_explode)
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 88195116-af81-42ac-a445-c7762ac581f9)

# %%
json_list = df_explode.toJSON().collect()
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 8, Finished, Available, Finished)

# %%
print(json_list[0])
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 11, Finished, Available, Finished)
# {"json_object":{"about":[{"name":"India","readLink":"https://api.bing.microsoft.com/api/v7/entities/85fa63d3-9596-adb9-b4eb-502273d84f56"},{"name":"Delhi","readLink":"https://api.bing.microsoft.com/api/v7/entities/275e8ab8-7bd0-4633-9c89-0133be92e587"},{"name":"Birla Mandir","readLink":"https://api.bing.microsoft.com/api/v7/entities/1bf686e3-6a32-3c6f-3549-7088fd3e0904"},{"name":"Mathura","readLink":"https://api.bing.microsoft.com/api/v7/entities/e463adf4-4666-d150-174c-0611cd51e27f"},{"name":"Shri Krishna","readLink":"https://api.bing.microsoft.com/api/v7/entities/1c759c74-79a1-3d93-94b0-2390da09e7d8"},{"name":"Madhya Pradesh","readLink":"https://api.bing.microsoft.com/api/v7/entities/bcbcd891-852b-6dac-1671-8d00b9eae5ea"},{"name":"Ujjain","readLink":"https://api.bing.microsoft.com/api/v7/entities/3e9f1dc5-180a-5ca2-c8ed-a427ae8fc886"},{"name":"Mahakaleshwar Jyotirlinga","readLink":"https://api.bing.microsoft.com/api/v7/entities/973ee89e-0543-27ab-a92c-4fc2ba0f5c23"}],"datePublished":"2024-08-26T09:53:00.0000000Z","description":"India TV News provides you with all the breaking news, latest news, breaking story videos, and Live TV on a single platform to ensure you don't miss the biggest happenings in India and the world.","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.AqdslnJI6-Ub9YshcCeSDS&pid=News","height":393,"width":700}},"name":"Breaking News, August 26 | LIVE updates","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.IaXDAOnJaO-iU5IbMMsMHw&pid=news"}},"name":"India TV"}],"url":"https://www.indiatvnews.com/news/india/breaking-news-august-26-live-updates-janmashtami-mathura-vrindavan-kolkata-rape-case-cbi-rg-kar-hospital-assembly-elections-pm-modi-congress-bjp-ups-948698"}}

# %%
import json
news_json = json.loads(json_list[0])
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 12, Finished, Available, Finished)

# %%
print(news_json)
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 13, Finished, Available, Finished)
# {'json_object': {'about': [{'name': 'India', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/85fa63d3-9596-adb9-b4eb-502273d84f56'}, {'name': 'Delhi', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/275e8ab8-7bd0-4633-9c89-0133be92e587'}, {'name': 'Birla Mandir', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/1bf686e3-6a32-3c6f-3549-7088fd3e0904'}, {'name': 'Mathura', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/e463adf4-4666-d150-174c-0611cd51e27f'}, {'name': 'Shri Krishna', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/1c759c74-79a1-3d93-94b0-2390da09e7d8'}, {'name': 'Madhya Pradesh', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/bcbcd891-852b-6dac-1671-8d00b9eae5ea'}, {'name': 'Ujjain', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/3e9f1dc5-180a-5ca2-c8ed-a427ae8fc886'}, {'name': 'Mahakaleshwar Jyotirlinga', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/973ee89e-0543-27ab-a92c-4fc2ba0f5c23'}], 'datePublished': '2024-08-26T09:53:00.0000000Z', 'description': "India TV News provides you with all the breaking news, latest news, breaking story videos, and Live TV on a single platform to ensure you don't miss the biggest happenings in India and the world.", 'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=OVFT.AqdslnJI6-Ub9YshcCeSDS&pid=News', 'height': 393, 'width': 700}}, 'name': 'Breaking News, August 26 | LIVE updates', 'provider': [{'_type': 'Organization', 'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ODF.IaXDAOnJaO-iU5IbMMsMHw&pid=news'}}, 'name': 'India TV'}], 'url': 'https://www.indiatvnews.com/news/india/breaking-news-august-26-live-updates-janmashtami-mathura-vrindavan-kolkata-rape-case-cbi-rg-kar-hospital-assembly-elections-pm-modi-congress-bjp-ups-948698'}}

# %%
print(news_json['json_object']['name'])
print(news_json['json_object']['description'])
print(news_json['json_object']['category'])
print(news_json['json_object']['url'])
print(news_json['json_object']['image']['thumbnail']['contentUrl'])
print(news_json['json_object']['provider'][0]['name'])
print(news_json['json_object']['datePublished'])
# Out:
# StatementMeta(, cdfaa5b7-53c3-41c8-9c6b-ef537a22473c, 16, Finished, Available, Finished)
# Breaking News, August 26 | LIVE updates
# India TV News provides you with all the breaking news, latest news, breaking story videos, and Live TV on a single platform to ensure you don't miss the biggest happenings in India and the world.
# https://www.indiatvnews.com/news/india/breaking-news-august-26-live-updates-janmashtami-mathura-vrindavan-kolkata-rape-case-cbi-rg-kar-hospital-assembly-elections-pm-modi-congress-bjp-ups-948698
# https://www.bing.com/th?id=OVFT.AqdslnJI6-Ub9YshcCeSDS&pid=News
# India TV
# 2024-08-26T09:53:00.0000000Z

# %%
title = []
description = []
category = []
url = []
image = []
provider = []
datePublished = []
#process each JSON object in the list
for json_str in json_list:
    try:
        #parsing JSON object into Dictionary
        artical = json.loads(json_str)
        title.append(artical["json_object"]["name"])
        description.append(artical["json_object"]["description"])
        category.append(artical["json_object"]["category"])
        url.append(artical["json_object"]["name"])
        title.append(artical["json_object"]["name"])
        title.append(artical["json_object"]["name"])


print(news_json['json_object']['name'])
print(news_json['json_object']['description'])
print(news_json['json_object']['category'])
print(news_json['json_object']['url'])
print(news_json['json_object']['image']['thumbnail']['contentUrl'])
print(news_json['json_object']['provider'][0]['name'])
print(news_json['json_object']['datePublished'])
